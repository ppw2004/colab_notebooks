# %% [markdown]
# <a href="https://colab.research.google.com/github/ppw2004/colab_notebooks/blob/main/gpu_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
print(f"CUDA 是否可用: {torch.cuda.is_available()}")

# 检查系统中有多少个 GPU
print(f"检测到的 GPU 数量: {torch.cuda.device_count()}")
# Out:
# CUDA 是否可用: True
# 检测到的 GPU 数量: 1
